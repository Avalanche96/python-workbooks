# %% [markdown]
# # Practice Exercise: Cleaning data & Transforming columns/features

# %% [markdown]
# ## Context:
# - The data is based on real anonymized Czech bank transactions and account info.
# - We'll be focusing on practicing the data cleaning, columns transformations, and other techniques that we've learned in the course.
# - But here is the original task description of the dataset publishers:
#
# *The bank wants to improve their services. For instance, the bank managers have only vague idea, who is a good client (whom to offer some additional services)   and who is a bad client (whom to watch carefully to minimize the bank losses). Fortunately, the bank stores data about their clients, the accounts (transactions within several months), the loans already granted, the credit cards issued. The bank managers hope to improve their understanding of customers and seek specific actions to improve services.*
#
# - We've made minor changes on the data to fit this exercise, such as changing the column names. Check out the original source if you are interested in using this data for other purposes (https://data.world/lpetrocelli/czech-financial-dataset-real-anonymized-transactions)

# %% [markdown]
# ## Dataset Description:
#
# We'll work on three datasets (in three separate csv files):
#
#   - **account**: each record describes static characteristics of an account
#   - **transaction**: each record describes one transaction on an account
#   - **district**: each record describes demographic characteristics of a district
#
# In reality, the organizations like banks often have data stored in multiple datasets. Assume we want to study the transactional level data, we'll need to combine these three datasets together to have transactions data with account and district data.

# %% [markdown]
# ## Objective:
#    - Examine/clean the individual dataset
#    - Combine them into a single dataset, which is subject to more cleaning
#    - Create new columns based on existing columns
#
# By the end, the new dataset is ready for more analysis.

# %% [markdown]
# ### 1. Import the libraries

# %%
import pandas as pd

# %% [markdown]
# ### 2. Import the data from three csv files as DataFrames `account`, `district`, `trans`
# Hint:
# - the `read_csv` function can automatically infer and load zip file, read its documentation of parameter `compression` if you are interested in details
# - you may ignore the warning when reading the `trans.csv.zip` file. It is optional to follow the warning instructions to remove it.

# %%
account=pd.read_csv('account.csv')

# %%
district=pd.read_csv('district.csv')

# %%
trans=pd.read_csv('trans.csv.zip')
# Out:
# C:\Users\David Moon\AppData\Local\Temp\ipykernel_21952\4170052465.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   trans=pd.read_csv('trans.csv.zip')

# %% [markdown]
# ### 3. Look at the info summary, head of each DataFrame

# %%
account.head()
# Out:
#    account_id  district_id           frequency account_open_date  client_id
# 0         576           55  MONTHLY STATEMENTS        1993-01-01        692
# 1        3818           74  MONTHLY STATEMENTS        1993-01-01       4601
# 2         704           55  MONTHLY STATEMENTS        1993-01-01        844
# 3        2378           16  MONTHLY STATEMENTS        1993-01-01       2873
# 4        2632           24  MONTHLY STATEMENTS        1993-01-02       3177

# %%
account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   account_id         4500 non-null   int64
#  1   district_id        4500 non-null   int64
#  2   frequency          4500 non-null   object
#  3   account_open_date  4500 non-null   object
#  4   client_id          4500 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 175.9+ KB

# %%
district.head()
# Out:
#    district_id district_name           region  population  average_salary  \
# 0            1   Hl.m. Praha           Prague     1204953         12541.0
# 1            2       Benesov  central Bohemia       88884             NaN
# 2            3        Beroun  central Bohemia       75232          8980.0
# 3            4        Kladno  central Bohemia      149893          9753.0
# 4            5         Kolin  central Bohemia       95616          9307.0
#
#    unemployment_rate  num_committed_crimes
# 0               0.43               99107.0
# 1                NaN                2674.0
# 2               2.21                2813.0
# 3               5.05                   NaN
# 4               4.43                   NaN

# %%
district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   district_id           76 non-null     int64
#  1   district_name         76 non-null     object
#  2   region                76 non-null     object
#  3   population            76 non-null     int64
#  4   average_salary        66 non-null     float64
#  5   unemployment_rate     66 non-null     float64
#  6   num_committed_crimes  67 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 4.3+ KB

# %%
trans.head()
# Out:
#    trans_id  account_id        date    type  operation_type  amount  balance  \
# 0    695247        2378  1993-01-01  CREDIT  CREDIT IN CASH   700.0    700.0
# 1    171812         576  1993-01-01  CREDIT  CREDIT IN CASH   900.0    900.0
# 2    207264         704  1993-01-01  CREDIT  CREDIT IN CASH  1000.0   1000.0
# 3   1117247        3818  1993-01-01  CREDIT  CREDIT IN CASH   600.0    600.0
# 4    579373        1972  1993-01-02  CREDIT  CREDIT IN CASH   400.0    400.0
#
#   description partner_bank  partner_account
# 0         NaN          NaN              NaN
# 1         NaN          NaN              NaN
# 2         NaN          NaN              NaN
# 3         NaN          NaN              NaN
# 4         NaN          NaN              NaN

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056320 entries, 0 to 1056319
# Data columns (total 10 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   trans_id         1056320 non-null  int64
#  1   account_id       1056320 non-null  int64
#  2   date             1056320 non-null  object
#  3   type             1056320 non-null  object
#  4   operation_type   873206 non-null   object
#  5   amount           1056320 non-null  float64
#  6   balance          1056320 non-null  float64
#  7   description      574439 non-null   object
#  8   partner_bank     273508 non-null   object
#  9   partner_account  295389 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 80.6+ MB

# %% [markdown]
# ### 4. Check for the unique values and their counts in each column for the three DataFrames

# %%
account.nunique()
# Out:
# account_id           4500
# district_id            77
# frequency               3
# account_open_date    1535
# client_id            4500
# dtype: int64

# %%
district.nunique()
# Out:
# district_id             76
# district_name           76
# region                   8
# population              76
# average_salary          65
# unemployment_rate       63
# num_committed_crimes    66
# dtype: int64

# %%
trans.nunique()
# Out:
# trans_id           1056320
# account_id            4500
# date                  2191
# type                     2
# operation_type           5
# amount               40400
# balance             542739
# description              8
# partner_bank            13
# partner_account       7665
# dtype: int64

# %% [markdown]
# ### 5. Check for duplicates in the three DataFrames

# %%
account[account.duplicated()]
# Out:
# Empty DataFrame
# Columns: [account_id, district_id, frequency, account_open_date, client_id]
# Index: []

# %%
district[district.duplicated()]
# Out:
# Empty DataFrame
# Columns: [district_id, district_name, region, population, average_salary, unemployment_rate, num_committed_crimes]
# Index: []

# %%
trans[trans.duplicated()]
# Out:
# Empty DataFrame
# Columns: [trans_id, account_id, date, type, operation_type, amount, balance, description, partner_bank, partner_account]
# Index: []

# %% [markdown]
# ### 6. Convert column `account_open_date` in `account` and column `date` in `trans` into datetime dtypes

# %%
account['account_open_date'] = pd.to_datetime(account['account_open_date'])

# %%
trans['date'] = pd.to_datetime(trans['date'])

# %%
account.dtypes
# Out:
# account_id                    int64
# district_id                   int64
# frequency                    object
# account_open_date    datetime64[ns]
# client_id                     int64
# dtype: object

# %%
trans.dtypes
# Out:
# trans_id                    int64
# account_id                  int64
# date               datetime64[ns]
# type                       object
# operation_type             object
# amount                    float64
# balance                   float64
# description                object
# partner_bank               object
# partner_account           float64
# dtype: object

# %% [markdown]
# ### 7. Convert the columns `region` and `district_name` in `district` to all uppercase

# %%
district['region'] = district['region'].str.upper()

# %%
district['district_name'] = district['district_name'].str.upper()

# %% [markdown]
# ### 8. Check for missing data by columns in `account` using the `isna` method

# %%
account.isna().sum()
# Out:
# account_id           0
# district_id          0
# frequency            0
# account_open_date    0
# client_id            0
# dtype: int64

# %% [markdown]
# ### 9. Check for missing data by columns in `district` using the `isna` method

# %%
district.isna().sum()
# Out:
# district_id              0
# district_name            0
# region                   0
# population               0
# average_salary          10
# unemployment_rate       10
# num_committed_crimes     9
# dtype: int64

# %% [markdown]
# `district` has numeric features that could have relationships with each other. Let's use iterative imputation on them.

# %% [markdown]
# #### Use `IterativeImputer` in `sklearn` to impute based on columns `population`, `average_salary`, `unemployment_rate`, `num_committed_crimes`

# %% [markdown]
# ##### Import libraries

# %%
from sklearn.experimental import enable_iterative_imputer

# %%
from sklearn.impute import IterativeImputer

# %% [markdown]
# ##### Build a list of columns that will be used for imputation, which are `population`, `average_salary`, `unemployment_rate`, `num_committed_crimes`
# These are the columns that might be related to each other

# %%
cols_to_impute=['population', 'average_salary', 'unemployment_rate', 'num_committed_crimes']

# %% [markdown]
# ##### Create `IterativeImputer` object and set its `min_value` and `max_value` parameters to be the minumum and maximum of corresponding columns

# %%
iter_imp = IterativeImputer(min_value=district[cols_to_impute].min(), max_value=district[cols_to_impute].max())

# %% [markdown]
# ##### Apply the imputer to fit and transform the columns to an imputed NumPy array

# %%
iter_imp.fit_transform(district[cols_to_impute])
# Out:
# array([[1.20495300e+06, 1.25410000e+04, 4.30000000e-01, 9.91070000e+04],
#        [8.88840000e+04, 8.81396950e+03, 3.76387269e+00, 2.67400000e+03],
#        [7.52320000e+04, 8.98000000e+03, 2.21000000e+00, 2.81300000e+03],
#        [1.49893000e+05, 9.75300000e+03, 5.05000000e+00, 6.31246351e+03],
#        [9.56160000e+04, 9.30700000e+03, 4.43000000e+00, 1.92027286e+03],
#        [7.79630000e+04, 8.54600000e+03, 4.02000000e+00, 3.12000000e+03],
#        [9.47250000e+04, 8.83600672e+03, 2.87000000e+00, 4.84600000e+03],
#        [1.12065000e+05, 8.90172995e+03, 1.44000000e+00, 4.98700000e+03],
#        [8.13440000e+04, 8.89900000e+03, 3.97000000e+00, 2.48700000e+03],
#        [9.20840000e+04, 1.01240000e+04, 5.40000000e-01, 1.63064296e+03],
#        [7.56370000e+04, 9.62200000e+03, 3.94888743e+00, 3.52900000e+03],
#        [1.07870000e+05, 8.75400000e+03, 4.31000000e+00, 3.86800000e+03],
#        [5.39210000e+04, 8.68147504e+03, 3.26000000e+00, 1.87500000e+03],
#        [1.77686000e+05, 1.00450000e+04, 1.71000000e+00, 6.29500000e+03],
#        [5.87960000e+04, 8.69995430e+03, 3.60000000e+00, 1.87900000e+03],
#        [9.39310000e+04, 8.42700000e+03, 1.54000000e+00, 1.91300000e+03],
#        [7.40620000e+04, 8.11400000e+03, 2.62000000e+00, 1.18100000e+03],
#        [7.06990000e+04, 8.96800000e+03, 3.35000000e+00, 1.91000000e+03],
#        [5.14280000e+04, 8.40200000e+03, 3.98000000e+00, 1.09900000e+03],
#        [7.06460000e+04, 8.54700000e+03, 3.64000000e+00, 1.54200000e+03],
#        [1.03347000e+05, 9.10400000e+03, 2.07000000e+00, 2.35400000e+03],
#        [5.84000000e+04, 8.62000000e+03, 1.25000000e+00, 1.11700000e+03],
#        [8.74190000e+04, 8.62400000e+03, 2.66000000e+00, 3.19800000e+03],
#        [1.22603000e+05, 8.99100000e+03, 2.01000000e+00, 5.27300000e+03],
#        [8.87570000e+04, 8.55400000e+03, 2.68000000e+00, 2.21800000e+03],
#        [1.70449000e+05, 1.07870000e+04, 4.88539238e+00, 6.26100000e+03],
#        [6.72980000e+04, 8.56100000e+03, 1.29000000e+00, 1.12700000e+03],
#        [7.25410000e+04, 8.59400000e+03, 2.01000000e+00, 1.52500000e+03],
#        [4.57140000e+04, 8.84300000e+03, 3.60000000e+00, 8.88000000e+02],
#        [9.48120000e+04, 8.83643429e+03, 3.67000000e+00, 2.80400000e+03],
#        [5.13130000e+04, 8.67160926e+03, 4.20000000e+00, 1.45200000e+03],
#        [1.05058000e+05, 9.27200000e+03, 3.22000000e+00, 4.50500000e+03],
#        [1.33777000e+05, 8.70500000e+03, 7.61000000e+00, 4.85900000e+03],
#        [1.25236000e+05, 9.67500000e+03, 7.68000000e+00, 5.19000000e+03],
#        [8.87680000e+04, 8.86700000e+03, 3.65829982e+00, 3.62000000e+03],
#        [1.59617000e+05, 9.19800000e+03, 4.28000000e+00, 6.13200000e+03],
#        [1.14006000e+05, 9.06500000e+03, 5.39000000e+00, 4.16600000e+03],
#        [8.58520000e+04, 8.96500000e+03, 3.79580871e+00, 2.82200000e+03],
#        [1.19895000e+05, 1.04460000e+04, 9.40000000e+00, 4.74300000e+03],
#        [1.28118000e+05, 9.31700000e+03, 7.07000000e+00, 4.55155099e+03],
#        [1.18650000e+05, 9.83200000e+03, 4.48000000e+00, 3.78271111e+03],
#        [9.59070000e+04, 8.38800000e+03, 2.94000000e+00, 1.66800000e+03],
#        [1.61854000e+05, 9.42500000e+03, 2.50000000e+00, 3.89100000e+03],
#        [1.05606000e+05, 8.25400000e+03, 3.76000000e+00, 2.32500000e+03],
#        [7.79170000e+04, 8.39000000e+03, 3.54306364e+00, 2.12200000e+03],
#        [1.12709000e+05, 8.36900000e+03, 2.31000000e+00, 2.61800000e+03],
#        [1.62580000e+05, 9.53800000e+03, 4.31564163e+00, 5.41000000e+03],
#        [7.89550000e+04, 9.06000000e+03, 2.44000000e+00, 1.71700000e+03],
#        [7.56850000e+04, 8.20800000e+03, 2.26000000e+00, 8.88000000e+02],
#        [1.02609000e+05, 8.18700000e+03, 5.45000000e+00, 2.13400000e+03],
#        [1.21947000e+05, 8.54100000e+03, 2.97000000e+00, 3.83900000e+03],
#        [1.39012000e+05, 8.36300000e+03, 3.49000000e+00, 5.43781794e+03],
#        [1.07911000e+05, 8.24000000e+03, 3.56000000e+00, 1.90300000e+03],
#        [3.87570000e+05, 9.94541831e+03, 1.96000000e+00, 1.86960000e+04],
#        [1.57042000e+05, 9.07227464e+03, 2.43000000e+00, 3.89400000e+03],
#        [1.24605000e+05, 8.77200000e+03, 3.95090019e+00, 3.15800000e+03],
#        [1.61954000e+05, 8.72000000e+03, 4.50000000e+00, 3.65100000e+03],
#        [1.09164000e+05, 8.75700000e+03, 3.95000000e+00, 2.47100000e+03],
#        [1.08871000e+05, 8.44400000e+03, 3.47000000e+00, 2.30500000e+03],
#        [1.10643000e+05, 8.44100000e+03, 4.48000000e+00, 2.25200000e+03],
#        [1.17897000e+05, 8.81400000e+03, 5.74000000e+00, 2.05900000e+03],
#        [1.45688000e+05, 8.54400000e+03, 1.86000000e+00, 2.90600000e+03],
#        [8.65130000e+04, 8.28800000e+03, 4.52000000e+00, 1.46000000e+03],
#        [1.97099000e+05, 9.62400000e+03, 4.78378483e+00, 4.26500000e+03],
#        [1.14200000e+05, 8.40300000e+03, 5.72000000e+00, 2.71800000e+03],
#        [1.25832000e+05, 8.51200000e+03, 4.12000000e+00, 2.10300000e+03],
#        [1.06054000e+05, 8.11000000e+03, 6.55000000e+00, 3.07900000e+03],
#        [2.28848000e+05, 9.89300000e+03, 4.72000000e+00, 1.27039356e+04],
#        [4.28210000e+04, 8.17300000e+03, 7.01000000e+00, 8.88000000e+02],
#        [2.85387000e+05, 1.01770000e+04, 7.75000000e+00, 1.01080000e+04],
#        [1.61227000e+05, 8.67800000e+03, 5.57000000e+00, 4.59500000e+03],
#        [2.26122000e+05, 9.33387873e+03, 4.79000000e+00, 9.20800000e+03],
#        [1.82027000e+05, 8.74600000e+03, 3.74000000e+00, 4.43300000e+03],
#        [3.23870000e+05, 1.06730000e+04, 5.44000000e+00, 1.83470000e+04],
#        [1.38032000e+05, 8.81900000e+03, 5.66000000e+00, 4.50500000e+03],
#        [1.27369000e+05, 8.36900000e+03, 3.81854058e+00, 2.80700000e+03]])

# %% [markdown]
# ##### Assign the imputed array back to the original DataFrame's columns

# %%
imputed_num = iter_imp.fit_transform(district[cols_to_impute])

# %% [markdown]
# ##### Double check that the columns are imputed

# %%
district[cols_to_impute]=imputed_num = iter_imp.fit_transform(district[cols_to_impute])

# %%
district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   district_id           76 non-null     int64
#  1   district_name         76 non-null     object
#  2   region                76 non-null     object
#  3   population            76 non-null     float64
#  4   average_salary        76 non-null     float64
#  5   unemployment_rate     76 non-null     float64
#  6   num_committed_crimes  76 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 4.3+ KB

# %% [markdown]
# ### 10. Check for missing data by columns in `trans` using the `isna` method

# %%
trans.isna().sum()
# Out:
# trans_id                0
# account_id              0
# date                    0
# type                    0
# operation_type     183114
# amount                  0
# balance                 0
# description        481881
# partner_bank       782812
# partner_account    760931
# dtype: int64

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056320 entries, 0 to 1056319
# Data columns (total 10 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   trans_id         1056320 non-null  int64
#  1   account_id       1056320 non-null  int64
#  2   date             1056320 non-null  datetime64[ns]
#  3   type             1056320 non-null  object
#  4   operation_type   873206 non-null   object
#  5   amount           1056320 non-null  float64
#  6   balance          1056320 non-null  float64
#  7   description      574439 non-null   object
#  8   partner_bank     273508 non-null   object
#  9   partner_account  295389 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(4)
# memory usage: 80.6+ MB

# %% [markdown]
# #### Divide the columns into numeric columns and categorical columns, then use the `fillna` method to fill numeric columns with -999, fill categorical columns with 'UNKNOWN'

# %%
numeric_trans=trans.select_dtypes(include = 'number').columns

# %%
cat_trans=trans.select_dtypes(exclude = 'number').columns

# %%
trans[numeric_trans]=trans[numeric_trans].fillna(-999)

# %%
trans[cat_trans] = trans[cat_trans].fillna('UNKNOWN')

# %%
trans[numeric_trans]
# Out:
#          trans_id  account_id  amount  balance  partner_account
# 0          695247        2378   700.0    700.0           -999.0
# 1          171812         576   900.0    900.0           -999.0
# 2          207264         704  1000.0   1000.0           -999.0
# 3         1117247        3818   600.0    600.0           -999.0
# 4          579373        1972   400.0    400.0           -999.0
# ...           ...         ...     ...      ...              ...
# 1056315   3626622        2906    62.3  13729.4           -999.0
# 1056316   3627616        2935    81.3  19544.9           -999.0
# 1056317   3625403        2869    60.2  14638.2           -999.0
# 1056318   3626683        2907   107.5  23453.0           -999.0
# 1056319   3626540        2902   164.1  41642.9           -999.0
#
# [1056320 rows x 5 columns]

# %%
trans[cat_trans]
# Out:
#               date    type  operation_type      description partner_bank
# 0       1993-01-01  CREDIT  CREDIT IN CASH          UNKNOWN      UNKNOWN
# 1       1993-01-01  CREDIT  CREDIT IN CASH          UNKNOWN      UNKNOWN
# 2       1993-01-01  CREDIT  CREDIT IN CASH          UNKNOWN      UNKNOWN
# 3       1993-01-01  CREDIT  CREDIT IN CASH          UNKNOWN      UNKNOWN
# 4       1993-01-02  CREDIT  CREDIT IN CASH          UNKNOWN      UNKNOWN
# ...            ...     ...             ...              ...          ...
# 1056315 1998-12-31  CREDIT         UNKNOWN  INTEREST CREDIT      UNKNOWN
# 1056316 1998-12-31  CREDIT         UNKNOWN  INTEREST CREDIT      UNKNOWN
# 1056317 1998-12-31  CREDIT         UNKNOWN  INTEREST CREDIT      UNKNOWN
# 1056318 1998-12-31  CREDIT         UNKNOWN  INTEREST CREDIT      UNKNOWN
# 1056319 1998-12-31  CREDIT         UNKNOWN  INTEREST CREDIT      UNKNOWN
#
# [1056320 rows x 5 columns]

# %% [markdown]
# ### 11. Check for outliers in `district` using the `describe` method, then look at the histograms of the suspicious columns

# %%
district.describe().T
# Out:
#                       count           mean            std       min  \
# district_id            76.0      38.500000      22.083176      1.00
# population             76.0  133692.000000  137812.665884  42821.00
# average_salary         76.0    8983.707247     740.959314   8110.00
# unemployment_rate      76.0       3.864003       1.721597      0.43
# num_committed_crimes   76.0    5054.492038   11392.279917    888.00
#
#                                25%            50%           75%        max
# district_id              19.750000      38.500000      57.25000       76.0
# population            84725.000000  108391.000000  138277.00000  1204953.0
# average_salary         8533.750000    8792.984750    9280.75000    12541.0
# unemployment_rate         2.650000       3.761936       4.57000        9.4
# num_committed_crimes   1918.454646    2864.000000    4562.41324    99107.0

# %%
district.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'district_id'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'average_salary'}>,
#         <Axes: title={'center': 'unemployment_rate'}>],
#        [<Axes: title={'center': 'num_committed_crimes'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# #### Explore the outliers in the dataset

# %%
district['population'].hist(bins=50)
# Out:
# <Axes: >

# %%
district['average_salary'].hist(bins=50)
# Out:
# <Axes: >

# %%
district[district['average_salary'] > 10000]
# Out:
#     district_id     district_name           region  population  \
# 0             1       HL.M. PRAHA           PRAGUE   1204953.0
# 9            10    PRAHA - VYCHOD  CENTRAL BOHEMIA     92084.0
# 13           14  CESKE BUDEJOVICE    SOUTH BOHEMIA    177686.0
# 25           26     PLZEN - MESTO     WEST BOHEMIA    170449.0
# 38           39              MOST    NORTH BOHEMIA    119895.0
# 69           70           KARVINA    NORTH MORAVIA    285387.0
# 73           74   OSTRAVA - MESTO    NORTH MORAVIA    323870.0
#
#     average_salary  unemployment_rate  num_committed_crimes
# 0          12541.0           0.430000          99107.000000
# 9          10124.0           0.540000           1630.642957
# 13         10045.0           1.710000           6295.000000
# 25         10787.0           4.885392           6261.000000
# 38         10446.0           9.400000           4743.000000
# 69         10177.0           7.750000          10108.000000
# 73         10673.0           5.440000          18347.000000

# %%
district[['district_id','population', 'average_salary']].sort_values(by = 'average_salary', ascending = False)
# Out:
#     district_id  population  average_salary
# 0             1   1204953.0         12541.0
# 25           26    170449.0         10787.0
# 73           74    323870.0         10673.0
# 38           39    119895.0         10446.0
# 69           70    285387.0         10177.0
# ..          ...         ...             ...
# 48           49     75685.0          8208.0
# 49           50    102609.0          8187.0
# 68           69     42821.0          8173.0
# 16           17     74062.0          8114.0
# 66           67    106054.0          8110.0
#
# [76 rows x 3 columns]

# %%
district['num_committed_crimes'].hist(bins=50)
# Out:
# <Axes: >

# %%
district[district['num_committed_crimes'] > 40000]
# Out:
#    district_id district_name  region  population  average_salary  \
# 0            1   HL.M. PRAHA  PRAGUE   1204953.0         12541.0
#
#    unemployment_rate  num_committed_crimes
# 0               0.43               99107.0

# %%
district[['num_committed_crimes', 'district_id', 'population']].sort_values(by = 'num_committed_crimes', ascending = False)
# Out:
#     num_committed_crimes  district_id  population
# 0           99107.000000            1   1204953.0
# 53          18696.000000           54    387570.0
# 73          18347.000000           74    323870.0
# 67          12703.935555           68    228848.0
# 69          10108.000000           70    285387.0
# ..                   ...          ...         ...
# 21           1117.000000           22     58400.0
# 18           1099.000000           19     51428.0
# 48            888.000000           49     75685.0
# 68            888.000000           69     42821.0
# 28            888.000000           29     45714.0
#
# [76 rows x 3 columns]

# %% [markdown]
# ### 12. Check for outliers in `trans` using the `describe` method, then look at the histograms of the suspicious columns

# %%
trans.describe()
# Out:
#            trans_id    account_id                           date  \
# count  1.056320e+06  1.056320e+06                        1056320
# mean   1.335311e+06  2.936867e+03  1997-01-04 07:29:27.037261952
# min    1.000000e+00  1.000000e+00            1993-01-01 00:00:00
# 25%    4.302628e+05  1.204000e+03            1996-01-16 00:00:00
# 50%    8.585065e+05  2.434000e+03            1997-04-10 00:00:00
# 75%    2.060979e+06  3.660000e+03            1998-02-28 00:00:00
# max    3.682987e+06  1.138200e+04            1998-12-31 00:00:00
# std    1.227487e+06  2.477345e+03                            NaN
#
#              amount       balance  partner_account
# count  1.056320e+06  1.056320e+06     1.056320e+06
# mean   5.924146e+03  3.851833e+04     1.277068e+07
# min    0.000000e+00 -4.112570e+04    -9.990000e+02
# 25%    1.359000e+02  2.240250e+04    -9.990000e+02
# 50%    2.100000e+03  3.314340e+04    -9.990000e+02
# 75%    6.800000e+03  4.960362e+04     3.410566e+06
# max    8.740000e+04  2.096370e+05     9.999420e+07
# std    9.522735e+03  2.211787e+04     2.613658e+07

# %% [markdown]
# #### Explore the outliers in the dataset

# %%
trans.hist(figsize = (20,20))
# Out:
# array([[<Axes: title={'center': 'trans_id'}>,
#         <Axes: title={'center': 'account_id'}>],
#        [<Axes: title={'center': 'date'}>,
#         <Axes: title={'center': 'amount'}>],
#        [<Axes: title={'center': 'balance'}>,
#         <Axes: title={'center': 'partner_account'}>]], dtype=object)

# %%
trans['balance'].hist(bins=50)
# Out:
# <Axes: >

# %%
trans['balance'].sort_values(ascending = False)
# Out:
# 545456     209637.0
# 505224     196106.5
# 851639     194119.3
# 7797       193909.9
# 1050758    192662.5
#              ...
# 900104     -40381.0
# 918568     -40581.0
# 925733     -40817.0
# 1020090    -40938.4
# 1027839    -41125.7
# Name: balance, Length: 1056320, dtype: float64

# %%
trans[trans['balance'] > 150000]
# Out:
#          trans_id  account_id       date    type  operation_type   amount  \
# 2832       695256        2378 1993-05-19  CREDIT  CREDIT IN CASH  43637.0
# 2872       576769        1965 1993-05-21  CREDIT  CREDIT IN CASH  33711.0
# 3037      1100776        3760 1993-05-29  CREDIT  CREDIT IN CASH  38405.0
# 7797       637133        2176 1993-08-02  CREDIT  CREDIT IN CASH  47024.0
# 16229      615555        2099 1993-10-18  CREDIT  CREDIT IN CASH  36684.0
# ...           ...         ...        ...     ...             ...      ...
# 1050134   3317727       11021 1998-12-24  CREDIT  CREDIT IN CASH  42890.0
# 1050758   2675921        8856 1998-12-26  CREDIT  CREDIT IN CASH  46170.0
# 1050912   3215715       10670 1998-12-27  CREDIT  CREDIT IN CASH  44890.0
# 1051009    157025         525 1998-12-27  CREDIT  CREDIT IN CASH  46726.0
# 1051504    656921        2245 1998-12-29  CREDIT  CREDIT IN CASH  40462.0
#
#           balance description partner_bank  partner_account
# 2832     151483.0     UNKNOWN      UNKNOWN           -999.0
# 2872     156483.5     UNKNOWN      UNKNOWN           -999.0
# 3037     169292.1     UNKNOWN      UNKNOWN           -999.0
# 7797     193909.9     UNKNOWN      UNKNOWN           -999.0
# 16229    184168.4     UNKNOWN      UNKNOWN           -999.0
# ...           ...         ...          ...              ...
# 1050134  160348.0     UNKNOWN      UNKNOWN           -999.0
# 1050758  192662.5     UNKNOWN      UNKNOWN           -999.0
# 1050912  173945.9     UNKNOWN      UNKNOWN           -999.0
# 1051009  158444.3     UNKNOWN      UNKNOWN           -999.0
# 1051504  161952.7     UNKNOWN      UNKNOWN           -999.0
#
# [354 rows x 10 columns]

# %%
trans[trans['balance'] < 0]
# Out:
#          trans_id  account_id       date    type      operation_type   amount  \
# 4703      1176458        4034 1993-06-28   DEBIT  WITHDRAWAL IN CASH  31840.0
# 4719      1693860        5740 1993-06-28   DEBIT  WITHDRAWAL IN CASH  10500.0
# 4808      1176550        4034 1993-06-30   DEBIT  WITHDRAWAL IN CASH     14.6
# 5026      3449868        4034 1993-06-30   DEBIT  WITHDRAWAL IN CASH      3.0
# 5027      3449867        4034 1993-06-30  CREDIT             UNKNOWN    102.5
# ...           ...         ...        ...     ...                 ...      ...
# 1055216   3607199        2335 1998-12-31   DEBIT  WITHDRAWAL IN CASH     36.3
# 1055220   3607198        2335 1998-12-31  CREDIT             UNKNOWN      6.6
# 1055233   3607597        2346 1998-12-31   DEBIT  WITHDRAWAL IN CASH     14.9
# 1055235   3607596        2346 1998-12-31  CREDIT             UNKNOWN     16.6
# 1055639   3489430        7520 1998-12-31   DEBIT  WITHDRAWAL IN CASH     67.2
#
#          balance            description partner_bank  partner_account
# 4703     -2994.6                UNKNOWN      UNKNOWN           -999.0
# 4719     -3724.7                UNKNOWN      UNKNOWN           -999.0
# 4808     -2906.6  PAYMENT FOR STATEMENT      UNKNOWN           -999.0
# 5026     -2909.6      INTEREST DEBITTED      UNKNOWN           -999.0
# 5027     -2892.0        INTEREST CREDIT      UNKNOWN           -999.0
# ...          ...                    ...          ...              ...
# 1055216  -2838.9      INTEREST DEBITTED      UNKNOWN           -999.0
# 1055220  -2785.5        INTEREST CREDIT      UNKNOWN           -999.0
# 1055233  -2236.2      INTEREST DEBITTED      UNKNOWN           -999.0
# 1055235  -2221.3        INTEREST CREDIT      UNKNOWN           -999.0
# 1055639 -11020.4      INTEREST DEBITTED      UNKNOWN           -999.0
#
# [2999 rows x 10 columns]

# %%
trans['amount'].hist(bins=50)
# Out:
# <Axes: >

# %%
trans['amount'].sort_values(ascending = False)
# Out:
# 1047413    87400.0
# 880698     87300.0
# 335550     86400.0
# 892659     85800.0
# 891095     81900.0
#             ...
# 108452         0.0
# 955267         0.0
# 132649         0.0
# 973793         0.0
# 584641         0.0
# Name: amount, Length: 1056320, dtype: float64

# %% [markdown]
# The DataFrame `account` doesn't have any columns that could have outliers, so we are not exploring it.

# %% [markdown]
# ### 13. Merge (left join) `account` and `district` into a new DataFrame called `account_district` using their common columns

# %%
account_district = pd.merge(account, district, on = 'district_id', how = 'left')

# %% [markdown]
# ### 14. Check the information summary of `account_district`, any missing data?

# %%
account_district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   account_id            4500 non-null   int64
#  1   district_id           4500 non-null   int64
#  2   frequency             4500 non-null   object
#  3   account_open_date     4500 non-null   datetime64[ns]
#  4   client_id             4500 non-null   int64
#  5   district_name         4460 non-null   object
#  6   region                4460 non-null   object
#  7   population            4460 non-null   float64
#  8   average_salary        4460 non-null   float64
#  9   unemployment_rate     4460 non-null   float64
#  10  num_committed_crimes  4460 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(3)
# memory usage: 386.8+ KB

# %% [markdown]
# #### Look at the rows with missing data in `account_district`

# %%
nan = account_district.isna().sum(axis = 1) > 0

# %%
account_district[nan]
# Out:
#       account_id  district_id                     frequency account_open_date  \
# 5           1972           77            MONTHLY STATEMENTS        1993-01-02
# 77          1000           77            MONTHLY STATEMENTS        1993-01-25
# 308          299           77            MONTHLY STATEMENTS        1993-04-05
# 322         8321           77            MONTHLY STATEMENTS        1993-04-12
# 394          551           77            MONTHLY STATEMENTS        1993-05-07
# 537         5228           77  STATEMENTS AFTER TRANSACTION        1993-06-23
# 574          368           77            MONTHLY STATEMENTS        1993-07-06
# 790         3157           77            MONTHLY STATEMENTS        1993-09-10
# 817          857           77            MONTHLY STATEMENTS        1993-09-16
# 832          153           77            MONTHLY STATEMENTS        1993-09-19
# 902         4119           77            MONTHLY STATEMENTS        1993-10-18
# 1161         742           77            MONTHLY STATEMENTS        1994-01-28
# 1331        1634           77            MONTHLY STATEMENTS        1994-06-04
# 1526        2377           77            MONTHLY STATEMENTS        1994-11-13
# 1622         217           77            MONTHLY STATEMENTS        1995-01-20
# 1716        3750           77            MONTHLY STATEMENTS        1995-03-18
# 1747        1590           77            MONTHLY STATEMENTS        1995-04-07
# 1806        2919           77            MONTHLY STATEMENTS        1995-05-10
# 1847          53           77            MONTHLY STATEMENTS        1995-06-07
# 2134        2157           77            MONTHLY STATEMENTS        1995-11-08
# 2336         976           77            MONTHLY STATEMENTS        1996-01-27
# 2392        1737           77            MONTHLY STATEMENTS        1996-02-13
# 2422         184           77            MONTHLY STATEMENTS        1996-02-21
# 2438        1962           77            MONTHLY STATEMENTS        1996-02-24
# 2451        1216           77            MONTHLY STATEMENTS        1996-03-01
# 2684        2994           77            MONTHLY STATEMENTS        1996-05-03
# 2709        3248           77            MONTHLY STATEMENTS        1996-05-11
# 2829        3647           77            MONTHLY STATEMENTS        1996-06-17
# 2881        7181           77  STATEMENTS AFTER TRANSACTION        1996-07-02
# 3002        4389           77            MONTHLY STATEMENTS        1996-07-28
# 3232        2332           77            MONTHLY STATEMENTS        1996-09-24
# 3372        1683           77            MONTHLY STATEMENTS        1996-11-01
# 3514        5817           77  STATEMENTS AFTER TRANSACTION        1996-12-10
# 3520        4631           77  STATEMENTS AFTER TRANSACTION        1996-12-12
# 3677        3990           77            MONTHLY STATEMENTS        1997-02-04
# 3723        4268           77            MONTHLY STATEMENTS        1997-02-20
# 3969        3172           77            MONTHLY STATEMENTS        1997-05-27
# 4050        2883           77            MONTHLY STATEMENTS        1997-06-29
# 4092        3833           77            MONTHLY STATEMENTS        1997-07-13
# 4137        3686           77            MONTHLY STATEMENTS        1997-08-03
#
#       client_id district_name region  population  average_salary  \
# 5          2397           NaN    NaN         NaN             NaN
# 77         1204           NaN    NaN         NaN             NaN
# 308         364           NaN    NaN         NaN             NaN
# 322       10275           NaN    NaN         NaN             NaN
# 394         664           NaN    NaN         NaN             NaN
# 537        6317           NaN    NaN         NaN             NaN
# 574         448           NaN    NaN         NaN             NaN
# 790        3817           NaN    NaN         NaN             NaN
# 817        1032           NaN    NaN         NaN             NaN
# 832         185           NaN    NaN         NaN             NaN
# 902        4959           NaN    NaN         NaN             NaN
# 1161        890           NaN    NaN         NaN             NaN
# 1331       1980           NaN    NaN         NaN             NaN
# 1526       2872           NaN    NaN         NaN             NaN
# 1622        262           NaN    NaN         NaN             NaN
# 1716       4524           NaN    NaN         NaN             NaN
# 1747       1927           NaN    NaN         NaN             NaN
# 1806       3527           NaN    NaN         NaN             NaN
# 1847         62           NaN    NaN         NaN             NaN
# 2134       2611           NaN    NaN         NaN             NaN
# 2336       1177           NaN    NaN         NaN             NaN
# 2392       2108           NaN    NaN         NaN             NaN
# 2422        224           NaN    NaN         NaN             NaN
# 2438       2387           NaN    NaN         NaN             NaN
# 2451       1468           NaN    NaN         NaN             NaN
# 2684       3616           NaN    NaN         NaN             NaN
# 2709       3928           NaN    NaN         NaN             NaN
# 2829       4398           NaN    NaN         NaN             NaN
# 2881       8667           NaN    NaN         NaN             NaN
# 3002       5287           NaN    NaN         NaN             NaN
# 3232       2820           NaN    NaN         NaN             NaN
# 3372       2043           NaN    NaN         NaN             NaN
# 3514       7043           NaN    NaN         NaN             NaN
# 3520       5579           NaN    NaN         NaN             NaN
# 3677       4811           NaN    NaN         NaN             NaN
# 3723       5143           NaN    NaN         NaN             NaN
# 3969       3836           NaN    NaN         NaN             NaN
# 4050       3485           NaN    NaN         NaN             NaN
# 4092       4619           NaN    NaN         NaN             NaN
# 4137       4444           NaN    NaN         NaN             NaN
#
#       unemployment_rate  num_committed_crimes
# 5                   NaN                   NaN
# 77                  NaN                   NaN
# 308                 NaN                   NaN
# 322                 NaN                   NaN
# 394                 NaN                   NaN
# 537                 NaN                   NaN
# 574                 NaN                   NaN
# 790                 NaN                   NaN
# 817                 NaN                   NaN
# 832                 NaN                   NaN
# 902                 NaN                   NaN
# 1161                NaN                   NaN
# 1331                NaN                   NaN
# 1526                NaN                   NaN
# 1622                NaN                   NaN
# 1716                NaN                   NaN
# 1747                NaN                   NaN
# 1806                NaN                   NaN
# 1847                NaN                   NaN
# 2134                NaN                   NaN
# 2336                NaN                   NaN
# 2392                NaN                   NaN
# 2422                NaN                   NaN
# 2438                NaN                   NaN
# 2451                NaN                   NaN
# 2684                NaN                   NaN
# 2709                NaN                   NaN
# 2829                NaN                   NaN
# 2881                NaN                   NaN
# 3002                NaN                   NaN
# 3232                NaN                   NaN
# 3372                NaN                   NaN
# 3514                NaN                   NaN
# 3520                NaN                   NaN
# 3677                NaN                   NaN
# 3723                NaN                   NaN
# 3969                NaN                   NaN
# 4050                NaN                   NaN
# 4092                NaN                   NaN
# 4137                NaN                   NaN

# %% [markdown]
# #### Use `SimpleImputer` from `sklearn` to impute the missing data in columns `population`, `average_salary`, `unemployment_rate`, `num_committed_crimes` with their means

# %%
from sklearn.impute import SimpleImputer

# %%
simple_imp_mean=SimpleImputer(strategy = 'mean')

# %%
account_district[cols_to_impute]=account_district[['population', 'average_salary', 'unemployment_rate', 'num_committed_crimes']]

# %%
simple_imp_mean.fit_transform(account_district[cols_to_impute])
# Out:
# array([[1.57042000e+05, 9.07227464e+03, 2.43000000e+00, 3.89400000e+03],
#        [3.23870000e+05, 1.06730000e+04, 5.44000000e+00, 1.83470000e+04],
#        [1.57042000e+05, 9.07227464e+03, 2.43000000e+00, 3.89400000e+03],
#        ...,
#        [9.48120000e+04, 8.83643429e+03, 3.67000000e+00, 2.80400000e+03],
#        [8.65130000e+04, 8.28800000e+03, 4.52000000e+00, 1.46000000e+03],
#        [1.20495300e+06, 1.25410000e+04, 4.30000000e-01, 9.91070000e+04]])

# %%
imputed_num=simple_imp_mean.fit_transform(account_district[cols_to_impute])

# %%
imputed_num.shape
# Out:
# (4500, 4)

# %%
account_district[cols_to_impute].shape
# Out:
# (4500, 4)

# %%
account_district[cols_to_impute] = imputed_num

# %%
account_district['average_salary'].value_counts(dropna = False)
# Out:
# average_salary
# 12541.000000    554
# 10177.000000    152
# 10673.000000    135
# 9945.418311     128
# 8369.000000     114
#                ...
# 8208.000000      37
# 9065.000000      37
# 8547.000000      36
# 8620.000000      36
# 8757.000000      32
# Name: count, Length: 76, dtype: int64

# %%
account_district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   account_id            4500 non-null   int64
#  1   district_id           4500 non-null   int64
#  2   frequency             4500 non-null   object
#  3   account_open_date     4500 non-null   datetime64[ns]
#  4   client_id             4500 non-null   int64
#  5   district_name         4460 non-null   object
#  6   region                4460 non-null   object
#  7   population            4500 non-null   float64
#  8   average_salary        4500 non-null   float64
#  9   unemployment_rate     4500 non-null   float64
#  10  num_committed_crimes  4500 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(3)
# memory usage: 386.8+ KB

# %% [markdown]
# #### Use `fillna` method to impute the missing data in columns `district_name` and `region` with 'UNKNOWN'

# %%
account_district=account_district.fillna('UNKNOWN')

# %%
account_district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   account_id            4500 non-null   int64
#  1   district_id           4500 non-null   int64
#  2   frequency             4500 non-null   object
#  3   account_open_date     4500 non-null   datetime64[ns]
#  4   client_id             4500 non-null   int64
#  5   district_name         4500 non-null   object
#  6   region                4500 non-null   object
#  7   population            4500 non-null   float64
#  8   average_salary        4500 non-null   float64
#  9   unemployment_rate     4500 non-null   float64
#  10  num_committed_crimes  4500 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(3)
# memory usage: 386.8+ KB

# %% [markdown]
# ### 15. Merge (left join) `trans` and `account_district` into a new DataFrame called `all_data` using their common columns

# %%
all_data = pd.merge(trans, account_district, on = 'account_id', how = 'left')

# %% [markdown]
# #### Check the information summary of `all_data`

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056320 entries, 0 to 1056319
# Data columns (total 20 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   trans_id              1056320 non-null  int64
#  1   account_id            1056320 non-null  int64
#  2   date                  1056320 non-null  datetime64[ns]
#  3   type                  1056320 non-null  object
#  4   operation_type        1056320 non-null  object
#  5   amount                1056320 non-null  float64
#  6   balance               1056320 non-null  float64
#  7   description           1056320 non-null  object
#  8   partner_bank          1056320 non-null  object
#  9   partner_account       1056320 non-null  float64
#  10  district_id           1056320 non-null  int64
#  11  frequency             1056320 non-null  object
#  12  account_open_date     1056320 non-null  datetime64[ns]
#  13  client_id             1056320 non-null  int64
#  14  district_name         1056320 non-null  object
#  15  region                1056320 non-null  object
#  16  population            1056320 non-null  float64
#  17  average_salary        1056320 non-null  float64
#  18  unemployment_rate     1056320 non-null  float64
#  19  num_committed_crimes  1056320 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(4), object(7)
# memory usage: 161.2+ MB

# %% [markdown]
# ### 16. Create a new column `account_open_year` and assign it as the year from column `account_open_date`

# %%
all_data['account_open_year'] = all_data['account_open_date'].dt.year

# %%
all_data['account_open_year'].head()
# Out:
# 0    1993
# 1    1993
# 2    1993
# 3    1993
# 4    1993
# Name: account_open_year, dtype: int32

# %% [markdown]
# ### 17. Calculate the difference between columns `date` (transaction date) and `account_open_date`

# %%
all_data['date'] - all_data['account_open_date']
# Out:
# 0            0 days
# 1            0 days
# 2            0 days
# 3            0 days
# 4            0 days
#              ...
# 1056315    832 days
# 1056316   1326 days
# 1056317    825 days
# 1056318   1939 days
# 1056319   2163 days
# Length: 1056320, dtype: timedelta64[ns]

# %% [markdown]
# ### 18. Create a new column `account_age_days` and assign it as the difference in days between columns `date` (transaction date) and `account_open_date`

# %%
all_data['account_age_days'] = (all_data['date'] - all_data['account_open_date'])/pd.Timedelta(days = 1)

# %%
all_data
# Out:
#          trans_id  account_id       date    type  operation_type  amount  \
# 0          695247        2378 1993-01-01  CREDIT  CREDIT IN CASH   700.0
# 1          171812         576 1993-01-01  CREDIT  CREDIT IN CASH   900.0
# 2          207264         704 1993-01-01  CREDIT  CREDIT IN CASH  1000.0
# 3         1117247        3818 1993-01-01  CREDIT  CREDIT IN CASH   600.0
# 4          579373        1972 1993-01-02  CREDIT  CREDIT IN CASH   400.0
# ...           ...         ...        ...     ...             ...     ...
# 1056315   3626622        2906 1998-12-31  CREDIT         UNKNOWN    62.3
# 1056316   3627616        2935 1998-12-31  CREDIT         UNKNOWN    81.3
# 1056317   3625403        2869 1998-12-31  CREDIT         UNKNOWN    60.2
# 1056318   3626683        2907 1998-12-31  CREDIT         UNKNOWN   107.5
# 1056319   3626540        2902 1998-12-31  CREDIT         UNKNOWN   164.1
#
#          balance      description partner_bank  partner_account  ...  \
# 0          700.0          UNKNOWN      UNKNOWN           -999.0  ...
# 1          900.0          UNKNOWN      UNKNOWN           -999.0  ...
# 2         1000.0          UNKNOWN      UNKNOWN           -999.0  ...
# 3          600.0          UNKNOWN      UNKNOWN           -999.0  ...
# 4          400.0          UNKNOWN      UNKNOWN           -999.0  ...
# ...          ...              ...          ...              ...  ...
# 1056315  13729.4  INTEREST CREDIT      UNKNOWN           -999.0  ...
# 1056316  19544.9  INTEREST CREDIT      UNKNOWN           -999.0  ...
# 1056317  14638.2  INTEREST CREDIT      UNKNOWN           -999.0  ...
# 1056318  23453.0  INTEREST CREDIT      UNKNOWN           -999.0  ...
# 1056319  41642.9  INTEREST CREDIT      UNKNOWN           -999.0  ...
#
#          account_open_date client_id      district_name         region  \
# 0               1993-01-01      2873  JINDRICHUV HRADEC  SOUTH BOHEMIA
# 1               1993-01-01       692      BRNO - VENKOV  SOUTH MORAVIA
# 2               1993-01-01       844      BRNO - VENKOV  SOUTH MORAVIA
# 3               1993-01-01      4601    OSTRAVA - MESTO  NORTH MORAVIA
# 4               1993-01-02      2397            UNKNOWN        UNKNOWN
# ...                    ...       ...                ...            ...
# 1056315         1996-09-20      3512             SEMILY   EAST BOHEMIA
# 1056316         1995-05-15      3545    FRYDEK - MISTEK  NORTH MORAVIA
# 1056317         1996-09-27      3468    FRYDEK - MISTEK  NORTH MORAVIA
# 1056318         1993-09-09      3513            KARVINA  NORTH MORAVIA
# 1056319         1993-01-28      3507         CESKA LIPA  NORTH BOHEMIA
#
#             population average_salary  unemployment_rate  \
# 0         93931.000000    8427.000000           1.540000
# 1        157042.000000    9072.274638           2.430000
# 2        157042.000000    9072.274638           2.430000
# 3        323870.000000   10673.000000           5.440000
# 4        270325.692377    9482.017843           3.571654
# ...                ...            ...                ...
# 1056315   75685.000000    8208.000000           2.260000
# 1056316  228848.000000    9893.000000           4.720000
# 1056317  228848.000000    9893.000000           4.720000
# 1056318  285387.000000   10177.000000           7.750000
# 1056319  105058.000000    9272.000000           3.220000
#
#          num_committed_crimes  account_open_year  account_age_days
# 0                 1913.000000               1993               0.0
# 1                 3894.000000               1993               0.0
# 2                 3894.000000               1993               0.0
# 3                18347.000000               1993               0.0
# 4                16486.170933               1993               0.0
# ...                       ...                ...               ...
# 1056315            888.000000               1996             832.0
# 1056316          12703.935555               1995            1326.0
# 1056317          12703.935555               1996             825.0
# 1056318          10108.000000               1993            1939.0
# 1056319           4505.000000               1993            2163.0
#
# [1056320 rows x 22 columns]

# %% [markdown]
# ### 19. Create a new column `amount_category` by cutting the column `amount` into 3 equal-sized bins, and label the bins as 'low_amount', 'medium_amount', 'high_amount'

# %%
all_data['amount_category'] = pd.qcut(all_data['amount'], q=3, labels=['low_amount', 'medium_amount', 'high_amount'])

# %% [markdown]
# #### Verify the categories and their counts in `amount_category`

# %%
all_data['amount_category'].value_counts()
# Out:
# amount_category
# medium_amount    352394
# low_amount       352118
# high_amount      351808
# Name: count, dtype: int64

# %% [markdown]
# ### 20. Create a new column `account_age_days_category` by cutting the column `account_age_days` into 5 equal-width bins

# %%
all_data['account_age_days_category'] = pd.cut(all_data['account_age_days'], bins = 5)

# %% [markdown]
# #### Verify the categories and their counts in `account_age_days_category`

# %%
all_data['account_age_days_category'].value_counts()
# Out:
# account_age_days_category
# (438.0, 876.0]      333012
# (-2.19, 438.0]      330815
# (876.0, 1314.0]     204014
# (1314.0, 1752.0]    131926
# (1752.0, 2190.0]     56553
# Name: count, dtype: int64

# %% [markdown]
# #### Print out the first 20 rows of `all_data` to look at the newly added columns

# %%
all_data.head(20)
# Out:
#     trans_id  account_id       date    type                operation_type  \
# 0     695247        2378 1993-01-01  CREDIT                CREDIT IN CASH
# 1     171812         576 1993-01-01  CREDIT                CREDIT IN CASH
# 2     207264         704 1993-01-01  CREDIT                CREDIT IN CASH
# 3    1117247        3818 1993-01-01  CREDIT                CREDIT IN CASH
# 4     579373        1972 1993-01-02  CREDIT                CREDIT IN CASH
# 5     771035        2632 1993-01-02  CREDIT                CREDIT IN CASH
# 6     452728        1539 1993-01-03  CREDIT                CREDIT IN CASH
# 7     725751        2484 1993-01-03  CREDIT                CREDIT IN CASH
# 8     497211        1695 1993-01-03  CREDIT                CREDIT IN CASH
# 9     232960         793 1993-01-03  CREDIT                CREDIT IN CASH
# 10    505240        1726 1993-01-03  CREDIT                CREDIT IN CASH
# 11    144541         485 1993-01-04  CREDIT                CREDIT IN CASH
# 12    637741        2177 1993-01-04  CREDIT                CREDIT IN CASH
# 13    689827        2357 1993-01-04  CREDIT                CREDIT IN CASH
# 14    846006        2881 1993-01-04  CREDIT                CREDIT IN CASH
# 15    637742        2177 1993-01-05  CREDIT  COLLECTION FROM ANOTHER BANK
# 16   2908688        9635 1993-01-05  CREDIT                CREDIT IN CASH
# 17    232961         793 1993-01-05  CREDIT  COLLECTION FROM ANOTHER BANK
# 18    192096         652 1993-01-05  CREDIT                CREDIT IN CASH
# 19    542215        1844 1993-01-06  CREDIT                CREDIT IN CASH
#
#     amount  balance description partner_bank  partner_account  ...  \
# 0    700.0    700.0     UNKNOWN      UNKNOWN           -999.0  ...
# 1    900.0    900.0     UNKNOWN      UNKNOWN           -999.0  ...
# 2   1000.0   1000.0     UNKNOWN      UNKNOWN           -999.0  ...
# 3    600.0    600.0     UNKNOWN      UNKNOWN           -999.0  ...
# 4    400.0    400.0     UNKNOWN      UNKNOWN           -999.0  ...
# 5   1100.0   1100.0     UNKNOWN      UNKNOWN           -999.0  ...
# 6    600.0    600.0     UNKNOWN      UNKNOWN           -999.0  ...
# 7   1100.0   1100.0     UNKNOWN      UNKNOWN           -999.0  ...
# 8    200.0    200.0     UNKNOWN      UNKNOWN           -999.0  ...
# 9    800.0    800.0     UNKNOWN      UNKNOWN           -999.0  ...
# 10  1000.0   1000.0     UNKNOWN      UNKNOWN           -999.0  ...
# 11   300.0    300.0     UNKNOWN      UNKNOWN           -999.0  ...
# 12   800.0    800.0     UNKNOWN      UNKNOWN           -999.0  ...
# 13   800.0    800.0     UNKNOWN      UNKNOWN           -999.0  ...
# 14   700.0    700.0     UNKNOWN      UNKNOWN           -999.0  ...
# 15  5123.0   5923.0     PENSION           YZ       62457513.0  ...
# 16   400.0    400.0     UNKNOWN      UNKNOWN           -999.0  ...
# 17  3401.0   4201.0     UNKNOWN           IJ        6149286.0  ...
# 18   700.0    700.0     UNKNOWN      UNKNOWN           -999.0  ...
# 19   500.0    500.0     UNKNOWN      UNKNOWN           -999.0  ...
#
#           district_name           region    population  average_salary  \
# 0     JINDRICHUV HRADEC    SOUTH BOHEMIA  9.393100e+04     8427.000000
# 1         BRNO - VENKOV    SOUTH MORAVIA  1.570420e+05     9072.274638
# 2         BRNO - VENKOV    SOUTH MORAVIA  1.570420e+05     9072.274638
# 3       OSTRAVA - MESTO    NORTH MORAVIA  3.238700e+05    10673.000000
# 4               UNKNOWN          UNKNOWN  2.703257e+05     9482.017843
# 5          KARLOVY VARY     WEST BOHEMIA  1.226030e+05     8991.000000
# 6           HL.M. PRAHA           PRAGUE  1.204953e+06    12541.000000
# 7       OSTRAVA - MESTO    NORTH MORAVIA  3.238700e+05    10673.000000
# 8               SUMPERK    NORTH MORAVIA  1.273690e+05     8369.000000
# 9             PARDUBICE     EAST BOHEMIA  1.625800e+05     9538.000000
# 10  RYCHNOV NAD KNEZNOU     EAST BOHEMIA  7.895500e+04     9060.000000
# 11           KUTNA HORA  CENTRAL BOHEMIA  7.796300e+04     8546.000000
# 12     UHERSKE HRADISTE    SOUTH MORAVIA  1.456880e+05     8544.000000
# 13           PRACHATICE    SOUTH BOHEMIA  5.142800e+04     8402.000000
# 14              KARVINA    NORTH MORAVIA  2.853870e+05    10177.000000
# 15     UHERSKE HRADISTE    SOUTH MORAVIA  1.456880e+05     8544.000000
# 16              KARVINA    NORTH MORAVIA  2.853870e+05    10177.000000
# 17            PARDUBICE     EAST BOHEMIA  1.625800e+05     9538.000000
# 18                TABOR    SOUTH BOHEMIA  1.033470e+05     9104.000000
# 19              CHRUDIM     EAST BOHEMIA  1.056060e+05     8254.000000
#
#    unemployment_rate num_committed_crimes  account_open_year  \
# 0           1.540000          1913.000000               1993
# 1           2.430000          3894.000000               1993
# 2           2.430000          3894.000000               1993
# 3           5.440000         18347.000000               1993
# 4           3.571654         16486.170933               1993
# 5           2.010000          5273.000000               1993
# 6           0.430000         99107.000000               1993
# 7           5.440000         18347.000000               1993
# 8           3.818541          2807.000000               1993
# 9           4.315642          5410.000000               1993
# 10          2.440000          1717.000000               1993
# 11          4.020000          3120.000000               1993
# 12          1.860000          2906.000000               1993
# 13          3.980000          1099.000000               1993
# 14          7.750000         10108.000000               1993
# 15          1.860000          2906.000000               1993
# 16          7.750000         10108.000000               1993
# 17          4.315642          5410.000000               1993
# 18          2.070000          2354.000000               1993
# 19          3.760000          2325.000000               1993
#
#     account_age_days  amount_category  account_age_days_category
# 0                0.0    medium_amount             (-2.19, 438.0]
# 1                0.0    medium_amount             (-2.19, 438.0]
# 2                0.0    medium_amount             (-2.19, 438.0]
# 3                0.0    medium_amount             (-2.19, 438.0]
# 4                0.0    medium_amount             (-2.19, 438.0]
# 5                0.0    medium_amount             (-2.19, 438.0]
# 6                0.0    medium_amount             (-2.19, 438.0]
# 7                0.0    medium_amount             (-2.19, 438.0]
# 8                0.0       low_amount             (-2.19, 438.0]
# 9                0.0    medium_amount             (-2.19, 438.0]
# 10               0.0    medium_amount             (-2.19, 438.0]
# 11               0.0    medium_amount             (-2.19, 438.0]
# 12               0.0    medium_amount             (-2.19, 438.0]
# 13               0.0    medium_amount             (-2.19, 438.0]
# 14               0.0    medium_amount             (-2.19, 438.0]
# 15               1.0      high_amount             (-2.19, 438.0]
# 16               0.0    medium_amount             (-2.19, 438.0]
# 17               2.0    medium_amount             (-2.19, 438.0]
# 18               0.0    medium_amount             (-2.19, 438.0]
# 19               0.0    medium_amount             (-2.19, 438.0]
#
# [20 rows x 24 columns]
