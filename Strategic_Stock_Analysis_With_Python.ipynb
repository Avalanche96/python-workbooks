# %% [markdown]
# Comparing Trading Volumes of Stocks With Python

# %%
import pandas as pd

aapl = pd.read_csv("aapl.csv")

aapl.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2022-02-01 00:00:00-05:00  174.009995  174.839996  172.309998  174.610001
# 1  2022-02-02 00:00:00-05:00  174.750000  175.880005  173.330002  175.839996
# 2  2022-02-03 00:00:00-05:00  174.479996  176.240005  172.119995  172.899994
# 3  2022-02-04 00:00:00-05:00  171.679993  174.100006  170.679993  172.389999
# 4  2022-02-07 00:00:00-05:00  172.860001  173.949997  170.949997  171.660004
#
#     Adj Close    Volume
# 0  173.602448  86213900
# 1  174.825348  84914300
# 2  171.902313  89418100
# 3  171.613632  82465400
# 4  170.886917  77251200

# %%
aapl.tail()
# Out:
#                           Date        Open        High         Low  \
# 246  2023-01-25 00:00:00-05:00  140.889999  142.429993  138.809998
# 247  2023-01-26 00:00:00-05:00  143.169998  144.250000  141.899994
# 248  2023-01-27 00:00:00-05:00  143.160004  147.229996  143.080002
# 249  2023-01-30 00:00:00-05:00  144.960007  145.550003  142.850006
# 250  2023-01-31 00:00:00-05:00  142.699997  144.339996  142.279999
#
#           Close   Adj Close    Volume
# 246  141.860001  141.860001  65799300
# 247  143.960007  143.960007  54105100
# 248  145.929993  145.929993  70492800
# 249  143.000000  143.000000  64015300
# 250  144.289993  144.289993  65874500

# %%
amzn = pd.read_csv("amzn_section_2.csv")

amzn.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2022-02-01 00:00:00-05:00  150.000000  151.707993  147.627502  151.193497
# 1  2022-02-02 00:00:00-05:00  155.050507  155.074997  148.863495  150.612503
# 2  2022-02-03 00:00:00-05:00  141.737503  144.247498  138.332993  138.845505
# 3  2022-02-04 00:00:00-05:00  155.606506  161.199997  150.608002  157.639496
# 4  2022-02-07 00:00:00-05:00  158.520004  162.690994  157.250000  157.935501
#
#     Adj Close     Volume
# 0  151.193497   59220000
# 1  150.612503   87330000
# 2  138.845505  225532000
# 3  157.639496  253456000
# 4  157.935501  102624000

# %%
amzn.tail()
# Out:
#                           Date        Open        High         Low  \
# 246  2023-01-25 00:00:00-05:00   92.559998   97.239998   91.519997
# 247  2023-01-26 00:00:00-05:00   98.239998   99.489998   96.919998
# 248  2023-01-27 00:00:00-05:00   99.529999  103.489998   99.529999
# 249  2023-01-30 00:00:00-05:00  101.089996  101.739998   99.010002
# 250  2023-01-31 00:00:00-05:00  101.160004  103.349998  101.139999
#
#           Close   Adj Close    Volume
# 246   97.180000   97.180000  94261600
# 247   99.220001   99.220001  68523600
# 248  102.239998  102.239998  87678100
# 249  100.550003  100.550003  70691900
# 250  103.129997  103.129997  66527300

# %%
csco = pd.read_csv("csco.csv")

csco.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2022-02-01 00:00:00-05:00  55.450001  55.500000  54.740002  55.369999
# 1  2022-02-02 00:00:00-05:00  55.230000  56.320000  55.169998  56.169998
# 2  2022-02-03 00:00:00-05:00  55.869999  56.150002  55.060001  55.200001
# 3  2022-02-04 00:00:00-05:00  54.889999  55.619999  54.389999  55.150002
# 4  2022-02-07 00:00:00-05:00  55.330002  55.529999  54.700001  55.169998
#
#    Adj Close    Volume
# 0  53.573200  22438500
# 1  54.347244  23316700
# 2  53.408722  19260500
# 3  53.360340  19675900
# 4  53.379692  14450200

# %%
csco.tail()
# Out:
#                           Date       Open       High        Low      Close  \
# 246  2023-01-25 00:00:00-05:00  47.980000  48.080002  47.230000  47.980000
# 247  2023-01-26 00:00:00-05:00  48.150002  48.470001  47.830002  48.340000
# 248  2023-01-27 00:00:00-05:00  48.099998  48.730000  47.970001  48.509998
# 249  2023-01-30 00:00:00-05:00  48.139999  48.500000  48.119999  48.220001
# 250  2023-01-31 00:00:00-05:00  48.119999  48.689999  48.049999  48.669998
#
#      Adj Close    Volume
# 246  47.980000  14638700
# 247  48.340000  12952700
# 248  48.509998  13414200
# 249  48.220001  19261900
# 250  48.669998  16821600

# %%
ford = pd.read_csv("ford.csv")

ford.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2022-02-01 00:00:00-05:00  20.610001  20.850000  19.920000  20.660000
# 1  2022-02-02 00:00:00-05:00  20.809999  21.049999  20.180000  20.629999
# 2  2022-02-03 00:00:00-05:00  20.170000  20.620001  19.870001  19.889999
# 3  2022-02-04 00:00:00-05:00  18.520000  18.590000  17.520000  17.959999
# 4  2022-02-07 00:00:00-05:00  17.730000  18.120001  17.700001  17.889999
#
#    Adj Close     Volume
# 0  20.110569  117651800
# 1  20.081366   95377600
# 2  19.361046  103016000
# 3  17.482370  211100500
# 4  17.414232   84610000

# %%
ford.tail()
# Out:
#                           Date   Open   High    Low  Close  Adj Close  \
# 246  2023-01-25 00:00:00-05:00  12.60  12.85  12.49  12.79      12.79
# 247  2023-01-26 00:00:00-05:00  12.99  13.07  12.71  12.92      12.92
# 248  2023-01-27 00:00:00-05:00  12.88  13.37  12.87  13.27      13.27
# 249  2023-01-30 00:00:00-05:00  13.01  13.20  12.86  12.89      12.89
# 250  2023-01-31 00:00:00-05:00  13.39  13.57  13.25  13.51      13.51
#
#        Volume
# 246  37739000
# 247  48970900
# 248  62066500
# 249  64512600
# 250  83093300

# %%
aapl_volume_average = aapl["Volume"].mean()

print(aapl_volume_average)
# Out:
# 85259773.70517929

# %%
amzn_volume_average = amzn["Volume"].mean()

print(amzn_volume_average)
# Out:
# 76075050.59760956

# %%
csco_volume_average = csco["Volume"].mean()

print(csco_volume_average)
# Out:
# 20673897.609561753

# %%
ford_volume_average = ford["Volume"].mean()

print(ford_volume_average)
# Out:
# 65473899.20318725

# %%
import numpy as np

volume_averages = np.array([aapl_volume_average, amzn_volume_average, csco_volume_average, ford_volume_average])

print(volume_averages)
# Out:
# [85259773.70517929 76075050.59760956 20673897.60956175 65473899.20318725]

# %%
import matplotlib.pyplot as pyplot

labels = ["Apple", "Amazon", "Cisco", "Ford"]

pyplot.rcParams["figure.figsize"] = (10, 10)

pyplot.rcParams.update({"font.size" : 20})

pyplot.pie(volume_averages, labels = labels, autopct = "%.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x1e357ebb230>,
# ...
#  [Text(0.5162243538966687, 0.9713456729938973, 'Apple'),
#   Text(-1.0999301106459403, 0.01239966509263741, 'Amazon'),
#   Text(-0.3812342189610647, -1.0318238562337794, 'Cisco'),
#   Text(0.7414388325668605, -0.8125690478734044, 'Ford')],
#  [Text(0.28157692030727377, 0.5298249125421257, '34.45'),
#   Text(-0.5999618785341492, 0.006763453686893133, '30.74'),
#   Text(-0.20794593761512617, -0.5628130124911523, '8.35'),
#   Text(0.4044211814001057, -0.44321948065822053, '26.46')])

# %%
aapl_closing_average = aapl["Close"].mean()

print(aapl_closing_average)
# Out:
# 152.11932260581696

# %%
amzn_closing_average = amzn["Close"].mean()

print(amzn_closing_average)
# Out:
# 121.21775516950751

# %%
csco_closing_average = csco["Close"].mean()

print(csco_closing_average)
# Out:
# 47.648884503489946

# %%
ford_closing_average = ford["Close"].mean()

print(ford_closing_average)
# Out:
# 14.090318721604062

# %%
closing_averages = np.array([aapl_closing_average, amzn_closing_average, csco_closing_average, ford_closing_average])

# %%
pyplot.pie(closing_averages, labels = labels, autopct = "%.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x1e357f63ef0>,
# ...
#  [Text(0.1584661948210632, 1.0885258219715934, 'Apple'),
#   Text(-0.7281430650801606, -0.8245045037934415, 'Amazon'),
#   Text(0.8335096960110228, -0.7178172376417362, 'Cisco'),
#   Text(1.0904150611782353, -0.14489649531878204, 'Ford')],
#  [Text(0.08643610626603447, 0.5937413574390509, '45.40'),
#   Text(-0.39716894458917845, -0.44972972934187716, '36.18'),
#   Text(0.4546416523696487, -0.3915366750773106, '14.22'),
#   Text(0.5947718515517646, -0.07903445199206292, '4.21')])

# %% [markdown]
# Finding the Lowest Risk Stocks With Python

# %%
aapl["Market Cap"] = aapl["Open"] * aapl["Volume"]

aapl.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2022-02-01 00:00:00-05:00  174.009995  174.839996  172.309998  174.610001
# 1  2022-02-02 00:00:00-05:00  174.750000  175.880005  173.330002  175.839996
# 2  2022-02-03 00:00:00-05:00  174.479996  176.240005  172.119995  172.899994
# 3  2022-02-04 00:00:00-05:00  171.679993  174.100006  170.679993  172.389999
# 4  2022-02-07 00:00:00-05:00  172.860001  173.949997  170.949997  171.660004
#
#     Adj Close    Volume    Market Cap
# 0  173.602448  86213900  1.500208e+10
# 1  174.825348  84914300  1.483877e+10
# 2  171.902313  89418100  1.560167e+10
# 3  171.613632  82465400  1.415766e+10
# 4  170.886917  77251200  1.335364e+10

# %%
amzn["Market Cap"] = amzn["Open"] * amzn["Volume"]

amzn.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2022-02-01 00:00:00-05:00  150.000000  151.707993  147.627502  151.193497
# 1  2022-02-02 00:00:00-05:00  155.050507  155.074997  148.863495  150.612503
# 2  2022-02-03 00:00:00-05:00  141.737503  144.247498  138.332993  138.845505
# 3  2022-02-04 00:00:00-05:00  155.606506  161.199997  150.608002  157.639496
# 4  2022-02-07 00:00:00-05:00  158.520004  162.690994  157.250000  157.935501
#
#     Adj Close     Volume    Market Cap
# 0  151.193497   59220000  8.883000e+09
# 1  150.612503   87330000  1.354056e+10
# 2  138.845505  225532000  3.196634e+10
# 3  157.639496  253456000  3.943940e+10
# 4  157.935501  102624000  1.626796e+10

# %%
csco["Market Cap"] = csco["Open"] * csco["Volume"]

csco.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2022-02-01 00:00:00-05:00  55.450001  55.500000  54.740002  55.369999
# 1  2022-02-02 00:00:00-05:00  55.230000  56.320000  55.169998  56.169998
# 2  2022-02-03 00:00:00-05:00  55.869999  56.150002  55.060001  55.200001
# 3  2022-02-04 00:00:00-05:00  54.889999  55.619999  54.389999  55.150002
# 4  2022-02-07 00:00:00-05:00  55.330002  55.529999  54.700001  55.169998
#
#    Adj Close    Volume    Market Cap
# 0  53.573200  22438500  1.244215e+09
# 1  54.347244  23316700  1.287781e+09
# 2  53.408722  19260500  1.076084e+09
# 3  53.360340  19675900  1.080010e+09
# 4  53.379692  14450200  7.995296e+08

# %%
ford["Market Cap"] = ford["Open"] * ford["Volume"]

ford.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2022-02-01 00:00:00-05:00  20.610001  20.850000  19.920000  20.660000
# 1  2022-02-02 00:00:00-05:00  20.809999  21.049999  20.180000  20.629999
# 2  2022-02-03 00:00:00-05:00  20.170000  20.620001  19.870001  19.889999
# 3  2022-02-04 00:00:00-05:00  18.520000  18.590000  17.520000  17.959999
# 4  2022-02-07 00:00:00-05:00  17.730000  18.120001  17.700001  17.889999
#
#    Adj Close     Volume    Market Cap
# 0  20.110569  117651800  2.424804e+09
# 1  20.081366   95377600  1.984808e+09
# 2  19.361046  103016000  2.077833e+09
# 3  17.482370  211100500  3.909581e+09
# 4  17.414232   84610000  1.500135e+09

# %%
aapl["Market Cap"].plot(label = "Apple", figsize = (20, 5))

amzn["Market Cap"].plot(label = "Amazon")

csco["Market Cap"].plot(label = "Cisco")

ford["Market Cap"].plot(label = "Ford")

pyplot.legend()

# %% [markdown]
# Finding the Most Traded Stock With Python

# %%
aapl["Volume"].plot(label = "Apple", figsize = (20, 5))

amzn["Volume"].plot(label = "Amazon")

csco["Volume"].plot(label = "Cisco")

ford["Volume"].plot(label = "Ford")

pyplot.legend()

# %% [markdown]
# Find Stock Trends With Moving Averages

# %%
aapl["MA50"] = aapl["Close"].rolling(50).mean()

aapl.tail()
# Out:
#                           Date        Open        High         Low  \
# 246  2023-01-25 00:00:00-05:00  140.889999  142.429993  138.809998
# 247  2023-01-26 00:00:00-05:00  143.169998  144.250000  141.899994
# 248  2023-01-27 00:00:00-05:00  143.160004  147.229996  143.080002
# 249  2023-01-30 00:00:00-05:00  144.960007  145.550003  142.850006
# 250  2023-01-31 00:00:00-05:00  142.699997  144.339996  142.279999
#
#           Close   Adj Close    Volume    Market Cap        MA50
# 246  141.860001  141.860001  65799300  9.270463e+09  139.268399
# 247  143.960007  143.960007  54105100  7.746227e+09  139.153599
# 248  145.929993  145.929993  70492800  1.009175e+10  139.106599
# 249  143.000000  143.000000  64015300  9.279658e+09  138.965799
# 250  144.289993  144.289993  65874500  9.400291e+09  138.875799

# %%
aapl["MA200"] = aapl["Close"].rolling(200).mean()

aapl.tail()
# Out:
#                           Date        Open        High         Low  \
# 246  2023-01-25 00:00:00-05:00  140.889999  142.429993  138.809998
# 247  2023-01-26 00:00:00-05:00  143.169998  144.250000  141.899994
# 248  2023-01-27 00:00:00-05:00  143.160004  147.229996  143.080002
# 249  2023-01-30 00:00:00-05:00  144.960007  145.550003  142.850006
# 250  2023-01-31 00:00:00-05:00  142.699997  144.339996  142.279999
#
#           Close   Adj Close    Volume    Market Cap        MA50      MA200
# 246  141.860001  141.860001  65799300  9.270463e+09  139.268399  148.52040
# 247  143.960007  143.960007  54105100  7.746227e+09  139.153599  148.38975
# 248  145.929993  145.929993  70492800  1.009175e+10  139.106599  148.29065
# 249  143.000000  143.000000  64015300  9.279658e+09  138.965799  148.16735
# 250  144.289993  144.289993  65874500  9.400291e+09  138.875799  148.03680

# %%
amzn["MA50"] = amzn["Close"].rolling(50).mean()

amzn["MA200"] = amzn["Close"].rolling(200).mean()

amzn.tail()
# Out:
#                           Date        Open        High         Low  \
# 246  2023-01-25 00:00:00-05:00   92.559998   97.239998   91.519997
# 247  2023-01-26 00:00:00-05:00   98.239998   99.489998   96.919998
# 248  2023-01-27 00:00:00-05:00   99.529999  103.489998   99.529999
# 249  2023-01-30 00:00:00-05:00  101.089996  101.739998   99.010002
# 250  2023-01-31 00:00:00-05:00  101.160004  103.349998  101.139999
#
#           Close   Adj Close    Volume    Market Cap     MA50       MA200
# 246   97.180000   97.180000  94261600  8.724853e+09  91.3290  113.688355
# 247   99.220001   99.220001  68523600  6.731758e+09  91.2976  113.412153
# 248  102.239998  102.239998  87678100  8.726601e+09  91.3726  113.167743
# 249  100.550003  100.550003  70691900  7.146244e+09  91.4048  112.916555
# 250  103.129997  103.129997  66527300  6.729902e+09  91.5250  112.654500

# %%
csco["MA50"] = csco["Close"].rolling(50).mean()

csco["MA200"] = csco["Close"].rolling(200).mean()

csco.tail()
# Out:
#                           Date       Open       High        Low      Close  \
# 246  2023-01-25 00:00:00-05:00  47.980000  48.080002  47.230000  47.980000
# 247  2023-01-26 00:00:00-05:00  48.150002  48.470001  47.830002  48.340000
# 248  2023-01-27 00:00:00-05:00  48.099998  48.730000  47.970001  48.509998
# 249  2023-01-30 00:00:00-05:00  48.139999  48.500000  48.119999  48.220001
# 250  2023-01-31 00:00:00-05:00  48.119999  48.689999  48.049999  48.669998
#
#      Adj Close    Volume    Market Cap     MA50     MA200
# 246  47.980000  14638700  7.023648e+08  47.8664  45.83005
# 247  48.340000  12952700  6.236725e+08  47.9374  45.80035
# 248  48.509998  13414200  6.452230e+08  48.0128  45.77850
# 249  48.220001  19261900  9.272679e+08  48.0792  45.76050
# 250  48.669998  16821600  8.094554e+08  48.1648  45.74310

# %%
ford["MA50"] = ford["Close"].rolling(50).mean()

ford["MA200"] = ford["Close"].rolling(200).mean()

ford.tail()
# Out:
#                           Date   Open   High    Low  Close  Adj Close  \
# 246  2023-01-25 00:00:00-05:00  12.60  12.85  12.49  12.79      12.79
# 247  2023-01-26 00:00:00-05:00  12.99  13.07  12.71  12.92      12.92
# 248  2023-01-27 00:00:00-05:00  12.88  13.37  12.87  13.27      13.27
# 249  2023-01-30 00:00:00-05:00  13.01  13.20  12.86  12.89      12.89
# 250  2023-01-31 00:00:00-05:00  13.39  13.57  13.25  13.51      13.51
#
#        Volume    Market Cap     MA50     MA200
# 246  37739000  4.755114e+08  12.9234  13.38000
# 247  48970900  6.361320e+08  12.8918  13.36935
# 248  62066500  7.994165e+08  12.8760  13.35930
# 249  64512600  8.393089e+08  12.8478  13.34695
# 250  83093300  1.112619e+09  12.8400  13.33695

# %% [markdown]
# Visualize Stock Moving Averages With Pyplot

# %%
figure, axes = pyplot.subplots(2, 2, figsize = (20, 10))

aapl["MA50"].plot(ax = axes [0, 0])
aapl["Close"].plot(ax = axes [0, 0])
aapl["MA200"].plot(ax = axes [0, 0])

amzn["MA50"].plot(ax = axes [0, 1])
amzn["Close"].plot(ax = axes [0, 1])
amzn["MA200"].plot(ax = axes [0, 1])

csco["MA50"].plot(ax = axes [1, 0])
csco["Close"].plot(ax = axes [1, 0])
csco["MA200"].plot(ax = axes [1, 0])

ford["MA50"].plot(ax = axes [1, 1])
ford["Close"].plot(ax = axes [1, 1])
ford["MA200"].plot(ax = axes [1, 1])
# Out:
# <Axes: >

# %% [markdown]
# Visuzalize Highest and Lowest Prices Reached by Stocks

# %%
aapl["High"].plot(label = "Apple", figsize = (20, 5))

amzn["High"].plot(label = "Amazon")

csco["High"].plot(label = "Cisco")

ford["High"].plot(label = "Ford")

pyplot.legend()

# %%
aapl["Low"].plot(label = "Apple", figsize = (20, 5))

amzn["Low"].plot(label = "Amazon")

csco["Low"].plot(label = "Cisco")

ford["Low"].plot(label = "Ford")

pyplot.legend()

# %% [markdown]
# Caluclating Stock Volatility with Python

# %%
aapl["Returns"] = (aapl["Close"] / aapl["Close"].shift(1)) -1

aapl.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2022-02-01 00:00:00-05:00  174.009995  174.839996  172.309998  174.610001
# 1  2022-02-02 00:00:00-05:00  174.750000  175.880005  173.330002  175.839996
# 2  2022-02-03 00:00:00-05:00  174.479996  176.240005  172.119995  172.899994
# 3  2022-02-04 00:00:00-05:00  171.679993  174.100006  170.679993  172.389999
# 4  2022-02-07 00:00:00-05:00  172.860001  173.949997  170.949997  171.660004
#
#     Adj Close    Volume    Market Cap  MA50  MA200   Returns
# 0  173.602448  86213900  1.500208e+10   NaN    NaN       NaN
# 1  174.825348  84914300  1.483877e+10   NaN    NaN  0.007044
# 2  171.902313  89418100  1.560167e+10   NaN    NaN -0.016720
# 3  171.613632  82465400  1.415766e+10   NaN    NaN -0.002950
# 4  170.886917  77251200  1.335364e+10   NaN    NaN -0.004235

# %%
aapl["Returns"].hist(bins = 100, label = "Apple")
# Out:
# <Axes: >

# %%
amzn["Returns"] = (amzn["Close"] / amzn["Close"].shift(1)) -1

csco["Returns"] = (csco["Close"] / csco["Close"].shift(1)) -1

ford["Returns"] = (ford["Close"] / ford["Close"].shift(1)) -1

# %%
figure, axes = pyplot.subplots(2, 2, figsize = (20, 10))

aapl["Returns"].hist(bins = 100, label = "Apple", ax = axes[0, 0])

amzn["Returns"].hist(bins = 100, label = "Amazon", ax = axes[0, 1])

csco["Returns"].hist(bins = 100, label = "Cisco", ax = axes[1, 0])

ford["Returns"].hist(bins = 100, label = "Ford", ax = axes[1, 1])
# Out:
# <Axes: >

# %%
aapl["Returns"].hist(bins = 100, label = "Apple", alpha = 0.5)

amzn["Returns"].hist(bins = 100, label = "Amazon", alpha = 0.5)

csco["Returns"].hist(bins = 100, label = "Cisco", alpha = 0.5)

ford["Returns"].hist(bins = 100, label = "Ford", alpha = 0.5)

pyplot.legend()

# %% [markdown]
# Calculate Correlations Between Stock Features

# %%
aapl.set_index("Date", inplace = True)

aapl.corr()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Open        1.000000  0.992154  0.991682  0.977003   0.976693 -0.081043
# High        0.992154  1.000000  0.992645  0.990535   0.990102 -0.049436
# Low         0.991682  0.992645  1.000000  0.991665   0.991615 -0.126822
# Close       0.977003  0.990535  0.991665  1.000000   0.999882 -0.089830
# Adj Close   0.976693  0.990102  0.991615  0.999882   1.000000 -0.094738
# Volume     -0.081043 -0.049436 -0.126822 -0.089830  -0.094738  1.000000
# Market Cap  0.234814  0.263423  0.187170  0.218601   0.213563  0.947355
# MA50        0.404927  0.419157  0.370321  0.379224   0.369884  0.440725
# MA200       0.518914  0.493563  0.464227  0.444985   0.444985  0.098011
# Returns    -0.077002  0.004500  0.012110  0.106319   0.108005 -0.074883
#
#             Market Cap      MA50     MA200   Returns
# Open          0.234814  0.404927  0.518914 -0.077002
# High          0.263423  0.419157  0.493563  0.004500
# ...

# %%
import seaborn

seaborn.heatmap(aapl.corr())
# Out:
# <Axes: >

# %%
amzn.set_index("Date", inplace = True)
csco.set_index("Date", inplace = True)
ford.set_index("Date", inplace = True)

# %%
seaborn.heatmap(amzn.corr())
# Out:
# <Axes: >

# %%
seaborn.heatmap(csco.corr())
# Out:
# <Axes: >

# %%
seaborn.heatmap(ford.corr(), annot = True)
# Out:
# <Axes: >
